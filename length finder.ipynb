# %%
import pandas as pan

# %%
import pandas as pan
b_url = pan.read_csv("Benign_list_big_final.csv")
b_url.columns=["URLs"]
fin_b = b_url.sample(n=5000,random_state=13).copy()
fin_b = fin_b.reset_index(drop = True)
fin_b.to_csv('legit_5000.csv',index=False)

# %%
f_url = pan.read_csv("legit_5000.csv")

# %%
list = []
def average(url):
    lnth=len(url)
    list.append(lnth)
    

for i in range(0,5000):
    url= f_url['URLs'][i]
    average(url)

avg = sum(list)/len(list)
print(avg)
# Out:
# 114.4682

# %%
## Phishing URL's

# %%
p_url = pan.read_csv("online-valid.csv")
fin_p = p_url.sample(n=5000,random_state=13).copy()
fin_p = fin_p.reset_index(drop = True)
fin_p.to_csv('phish_5000.csv',index=False)
f_p_url = pan.read_csv("phish_5000.csv")

# %%
list = []
def average(url):
    lnth=len(url)
    list.append(lnth)
    

for i in range(0,5000):
    url= f_p_url['url'][i]
    average(url)

avg = sum(list)/len(list)
print(avg)
print(list)
# Out:
# 71.3056
# ...
